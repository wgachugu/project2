# %% [markdown]
# # Configuration

# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config_file import username, password, port, database

# %% [markdown]
# ## Establish connection to PostgreSQL

# %%
engine = create_engine(f'postgresql://{username}:{password}@localhost:{port}/{database}')
connection = engine.connect()

# %% [markdown]
# ## Store Museums Data CSV files into DataFrames

# %% [markdown]
# ##### Extract datasets and store into DataFrames

# %%
# store Museums_FY2013 file into DataFrame
file_path1 = "../Resources/Museums_FY2013.csv"
museums_FY2013 = pd.read_csv(file_path1, encoding="utf8")
museums_FY2013.head()
# Out:
#                                          Museum.Name  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM
# 1                            ALASKA BOTANICAL GARDEN
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3                             ALASKA HERITAGE MUSEUM
# 4                               ALASKA JEWISH MUSEUM
#
#                                           Legal.Name  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM
# 1                        ALASKA BOTANICAL GARDEN INC
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3                    ALASKA AVIATION HERITAGE MUSEUM
# 4  ALASKA JEWISH HISTORICAL MUSEUM AND CULTURAL C...
#
#                                      Museum.Type  \
# 0                                 HISTORY MUSEUM
# 1  ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER
# 2     SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM
# 3                                 HISTORY MUSEUM
# 4                                 GENERAL MUSEUM
#
#   State..Administrative.Location.  Region.Code..AAM.  Is.Museum  Tax.Year  \
# 0                              AK                  6       True      2013
# 1                              AK                  6      False      2013
# 2                              AK                  6       True      2013
# 3                              AK                  6       True      2013
# 4                              AK                  6       True      2013
#
#    Annual.Revenue
# 0       1100472.0
# 1       1323742.0
# 2        729080.0
# 3       1100472.0
# 4         68748.0

# %%
# store Museums_FY2015 file into DataFrame
file_path2 = "../Resources/Museums_FY2015_v2.csv"
museums_FY2015 = pd.read_csv(file_path2, delimiter=',')
museums_FY2015.head()
# Out:
# C:\Users\dmostacero\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (9,15,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           MID                                      COMMONNAME  \
# 0  8400200185                  SITKA NATIONAL HISTORICAL PARK
# 1  8400200181               KATMAI NATIONAL PARK AND PRESERVE
# 2  8400200178  GATES OF THE ARCTIC NATIONAL PARK AND PRESERVE
# 3  8400200023                             COLONY HOUSE MUSEUM
# 4  8400200014                  KODIAK MILITARY HISTORY MUSEUM
#
#                                         LEGALNAME ALTNAME AKADBA  \
# 0                  SITKA NATIONAL HISTORICAL PARK     NaN    NaN
# 1               KATMAI NATIONAL PARK AND PRESERVE     NaN    NaN
# 2  GATES OF THE ARCTIC NATIONAL PARK AND PRESERVE     NaN    NaN
# 3                             COLONY HOUSE MUSEUM     NaN    NaN
# 4                  KODIAK MILITARY HISTORY MUSEUM     NaN    NaN
#
#                 ADSTREET       ADCITY ADSTATE  ADZIP ADZIP5  ... CENTRACT  \
# 0  106 METLAKATLA STREET        SITKA      AK  99835  99835  ...    200.0
# 1               PO BOX 7  KING SALMON      AK  99613  99613  ...    100.0
# 2        4175 GEIST ROAD    FAIRBANKS      AK  99709  99709  ...    800.0
# 3      316 E ELMWOOD AVE       PALMER      AK  99645  99645  ...   1201.0
# 4       1417 MILL BAY RD       KODIAK      AK  99615  99615  ...    200.0
#
#   CENBLOCK CONGDIST      FULLFIPS                GSTREET        GCITY GSTATE  \
# 0   4000.0      0.0  2.220000e+13  106 METLAKATLA STREET        SITKA     AK
# 1   1000.0      0.0  2.060000e+13               PO BOX 7  KING SALMON     AK
# 2   2000.0      0.0  2.090000e+13        4175 GEIST ROAD    FAIRBANKS     AK
# 3   2017.0      0.0  2.170000e+13      316 E ELMWOOD AVE       PALMER     AK
# 4   3005.0      0.0  2.150000e+13       1417 MILL BAY RD       KODIAK     AK
#
#     GZIP  GZIP5 BMF15_F
# 0  99835  99835       0
# 1  99613  99613       0
# 2  99709  99709       0
# 3  99645  99645       0
# 4  99615  99615       0
#
# [5 rows x 44 columns]

# %%
# store Museums_Locations file into DataFrame
file_path3 = "../Resources/Museums_Locations.csv"
museums_Locations = pd.read_csv(file_path3, encoding="utf8")
museums_Locations.head()
# Out:
# C:\Users\dmostacero\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (14,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#     Museum ID                                        Museum Name  \
# 0  8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1  8400200117                            ALASKA BOTANICAL GARDEN
# 2  8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3  8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4  8400200027                             ALASKA HERITAGE MUSEUM
#
#                                           Legal Name Alternate Name  \
# 0                    ALASKA AVIATION HERITAGE MUSEUM            NaN
# 1                        ALASKA BOTANICAL GARDEN INC            NaN
# 2  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...            NaN
# 3                ALASKA EDUCATORS HISTORICAL SOCIETY            NaN
# 4                    ALASKA AVIATION HERITAGE MUSEUM            NaN
#
#                                      Museum Type Institution Name  \
# 0                                 HISTORY MUSEUM              NaN
# 1  ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER              NaN
# 2     SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM              NaN
# 3                          HISTORIC PRESERVATION              NaN
# 4                                 HISTORY MUSEUM              NaN
#
#   Street Address (Administrative Location) City (Administrative Location)  \
# 0                         4721 AIRCRAFT DR                      ANCHORAGE
# 1                4601 CAMPBELL AIRSTRIP RD                      ANCHORAGE
# 2                      9711 KENAI SPUR HWY                          KENAI
# 3                         214 BIRCH STREET                          KENAI
# 4               301 W NORTHERN LIGHTS BLVD                      ANCHORAGE
#
#   State (Administrative Location)  Zip Code (Administrative Location)  ...  \
# 0                              AK                               99502  ...
# 1                              AK                               99507  ...
# 2                              AK                               99611  ...
# 3                              AK                               99611  ...
# 4                              AK                               99503  ...
#
#    Latitude  Longitude Locale Code (NCES)  County Code (FIPS)  \
# 0  61.17925 -149.97254                1.0                20.0
# 1  61.16890 -149.76708                4.0                20.0
# 2  60.56149 -151.21598                3.0               122.0
# 3  60.56280 -151.26597                3.0               122.0
# 4  61.17925 -149.97254                1.0                20.0
#
#   State Code (FIPS)  Region Code (AAM)  Employer ID Number  Tax Period  \
# 0               2.0                  6           920071852    201312.0
# 1               2.0                  6           920115504    201312.0
# 2               2.0                  6           921761906    201312.0
# 3               2.0                  6           920165178    201412.0
# 4               2.0                  6           920071852    201312.0
#
#       Income    Revenue
# 0   602912.0   550236.0
# 1  1379576.0  1323742.0
# 2   740030.0   729080.0
# 3        0.0        0.0
# 4   602912.0   550236.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Transform and clean Museums DataFrames

# %% [markdown]
# ##### Transform 'museums_FY2013' DataFrame

# %%
# create a filtered dataframe from specific columns
museums_FY2013_transformed = museums_FY2013[['Museum.Name', 'Legal.Name', 'Annual.Revenue', 'Region.Code..AAM.']].copy()

# rename the column headers
museums_FY2013_transformed = museums_FY2013_transformed.rename(columns={"Museum.Name": "Museum_name",
                                                          "Legal.Name": "Legal_name",
                                                          "Annual.Revenue": "Revenue_2013",
                                                             "Region.Code..AAM.":"Region_code"})

# clean the data by dropping duplicates 
museums_FY2013_transformed = museums_FY2013_transformed.drop_duplicates(subset=["Legal_name"])

# sort by 'legal name' in alphabetical order
museums_FY2013_transformed = museums_FY2013_transformed.sort_values(by=['Legal_name'])

# reset the index
museums_FY2013_transformed = museums_FY2013_transformed.reset_index(drop=True)

# rename the index
museums_FY2013_transformed.index.name = 'FY2013ID'

museums_FY2013_transformed.head()
# Out:
#                                                Museum_name  \
# FY2013ID
# 0                           102ND INFANTRY REGIMENT MUSEUM
# 1                                             1078 GALLERY
# 2                    12TH ARMORED DIVISION MEMORIAL MUSEUM
# 3                                             1708 GALLERY
# 4         1844 CONCORD SCHOOL LOG CABIN HISTORICAL SOCIETY
#
#                                                  Legal_name  Revenue_2013  \
# FY2013ID
# 0                        102ND INFANTRY REGIMENT MUSEUM INC           0.0
# 1                                          1078 GALLERY INC       42031.0
# 2         12TH ARMORED DIVISION MEMORIAL MUSEUM FOUNDATI...      425152.0
# 3                                          1708 GALLERY INC      328248.0
# 4          1844 CONCORD SCHOOL LOG CABIN HISTORICAL SOCIETY           0.0
#
#           Region_code
# FY2013ID
# 0                   1
# 1                   6
# 2                   5
# 3                   3
# 4                   4

# %% [markdown]
# ##### Transform 'museums_FY2015' DataFrame

# %%
# create a filtered dataframe from specific columns
museums_FY2015_transformed = museums_FY2015[['COMMONNAME', 'LEGALNAME', 'PHONE', 
                                                        'WEBURL', 'REVENUE', 'LONGITUDE', 'LATITUDE']].copy()

# rename the column headers
museums_FY2015_transformed = museums_FY2015_transformed.rename(columns={"COMMONNAME": "Common_name",
                                                          "LEGALNAME": "Legal_name",
                                                          "PHONE": "Phone",
                                                            "WEBURL":"Weburl",
                                                            "REVENUE":"Revenue_2015",
                                                             "LONGITUDE":"Long",                   
                                                            "LATITUDE":"Lat",})


# clean the data by dropping duplicates 
museums_FY2015_transformed = museums_FY2015_transformed.drop_duplicates(subset=["Legal_name"])
# len(museums_FY2015_transformed)

# clean the data by replacing NaN rows with string values on select columns
museums_FY2015_transformed[['Common_name', 'Weburl']] = museums_FY2015_transformed[['Common_name', 'Weburl']].fillna('')

# clean the data by replacing NaN rows with 0 values on select columns
museums_FY2015_transformed[['Phone']] = museums_FY2015_transformed[['Phone']].fillna(0)

museums_FY2015_transformed['Phone'] = (
    pd.to_numeric(museums_FY2015_transformed['Phone'],
                  errors='coerce')
      .fillna(0)
    )


# clean the data by replacing NaN rows with zeros on select columns
#museums_FY2015_transformed[['Revenue_2015', 'Long', 'Lat']] = museums_FY2015_transformed[['Revenue_2015', 'Long', 'Lat']].fillna('0')

# sort by 'legal name' in alphabetical order
museums_FY2015_transformed = museums_FY2015_transformed.sort_values(by=['Legal_name'])

# reset the index
museums_FY2015_transformed = museums_FY2015_transformed.reset_index(drop=True)

# rename the index
museums_FY2015_transformed.index.name = 'FY2015ID'

museums_FY2015_transformed.head()
# museums_FY2015_transformed.dtypes
# museums_FY2015_transformed.columns
# Out:
#                                              Common_name  \
# FY2015ID
# 0                                  100TH MERIDIAN MUSEUM
# 1                         102ND INFANTRY REGIMENT MUSEUM
# 2         103RD OHIO VOLUNTEER INFANTRY CIVIL WAR MUSEUM
# 3                                           1078 GALLERY
# 4                                       FORT DRUM MUSEUM
#
#                                          Legal_name         Phone  \
# FY2015ID
# 0                             100TH MERIDIAN MUSEUM  3.087841e+09
# 1                102ND INFANTRY REGIMENT MUSEUM INC  2.037847e+09
# 2                     103RD OVI MEMORIAL FOUNDATION  4.409493e+09
# 3                                  1078 GALLERY INC  5.303432e+09
# 4         10TH MOUNTAIN DIVISION & FORT DRUM MUSEUM  3.157740e+09
#
#                                                      Weburl  Revenue_2015  \
# FY2015ID
# 0                                                                     NaN
# 1                                   HTTP://WHMILMUSEUM.COM/           0.0
# 2                                                                 13913.0
# 3                                                                 42031.0
# 4         HTTP://WWW.DRUM.ARMY.MIL/ABOUTFORTDRUM/PAGES/F...           NaN
#
#                Long       Lat
# FY2015ID
# 0         -99.98338  40.85963
# 1         -72.96175  41.27210
# 2         -82.06886  41.50073
# 3        -121.83653  39.72540
# 4         -75.77208  44.04050

# %% [markdown]
# ##### Transform 'museums_Locations' DataFrame

# %%
# create a filtered dataframe from specific columns
museums_Locations_transformed = museums_Locations[['Museum Name', 'Legal Name', 'Museum Type', 
                                                        'Street Address (Administrative Location)', 
                                                        'City (Administrative Location)', 
                                                              'State (Administrative Location)', 
                                                              'Zip Code (Administrative Location)']].copy()

# rename the column headers
museums_Locations_transformed = museums_Locations_transformed.rename(columns={"Museum Name": "Museum_name",
                                                          "Legal Name": "Legal_name",
                                                          "Museum Type": "Museum_type",
                                                            "Street Address (Administrative Location)":"Street_address",
                                                            "City (Administrative Location)":"City",
                                                             "State (Administrative Location)":"State",                   
                                                            "Zip Code (Administrative Location)":"Zip_code",})


# clean the data by dropping duplicates 
museums_Locations_transformed = museums_Locations_transformed.drop_duplicates(subset=["Legal_name"])
# len(museums_Locations_transformed)

# clean the data by replacing NaN rows with string values on select columns
museums_Locations_transformed[['Street_address', 'City', 'State', 'Zip_code']] = museums_Locations_transformed[['Street_address', 'City', 'State', 'Zip_code']].fillna('')
# len(museums_Locations_transformed_vF)

# sort by 'legal name' in alphabetical order
museums_Locations_transformed = museums_Locations_transformed.sort_values(by=['Legal_name'])

# reset the index
museums_Locations_transformed = museums_Locations_transformed.reset_index(drop=True)

# rename the index
museums_Locations_transformed.index.name = 'LocationID'

museums_Locations_transformed.head()
# museums_Locations_transformed.columns
# museums_Locations_transformed.dtypes
# Out:
#                                                Museum_name  \
# LocationID
# 0                                    100TH MERIDIAN MUSEUM
# 1                           102ND INFANTRY REGIMENT MUSEUM
# 2           103RD OHIO VOLUNTEER INFANTRY CIVIL WAR MUSEUM
# 3                                             1078 GALLERY
# 4                                         FORT DRUM MUSEUM
#
#                                            Legal_name     Museum_type  \
# LocationID
# 0                               100TH MERIDIAN MUSEUM  GENERAL MUSEUM
# 1                  102ND INFANTRY REGIMENT MUSEUM INC  GENERAL MUSEUM
# 2                       103RD OVI MEMORIAL FOUNDATION  GENERAL MUSEUM
# 3                                    1078 GALLERY INC      ART MUSEUM
# 4           10TH MOUNTAIN DIVISION & FORT DRUM MUSEUM  GENERAL MUSEUM
#
#                                      Street_address        City State  \
# LocationID
# 0                                      206 E 8TH ST       COZAD    NE
# 1                                   30 HOOD TERRACE  WEST HAVEN    CT
# 2                                5501 E LAKE RD OFC      LORAIN    OH
# 3                                   820 BROADWAY ST       CHICO    CA
# 4           BUILDING P-10502, SOUTH RIVA RIDGE LOOP   FORT DRUM    NY
#
#             Zip_code
# LocationID
# 0              69130
# 1               6516
# 2              44054
# 3              95928
# 4              13602

# %% [markdown]
# ## Load DataFrames into database

# %%
# Confirm tables
engine.table_names()
# Out:
# ['museums_location', 'museums_fy2013', 'museums_directory', 'museums_fy2015']

# %%
# load 1st of 3 DataFrames into postgres database
museums_Locations_transformed.to_sql(name='museums_location', con=engine, if_exists='append', index=True)

# %%
# load 2nd of 3 DataFrames into postgres database
museums_FY2013_transformed.to_sql(name='museums_fy2013', con=engine, if_exists='append', index=True)

# %%
# load 3rd of 3 DataFrames into postgres database
museums_FY2015_transformed.to_sql(name='museums_fy2015', con=engine, if_exists='append', index=True)

# %%
# confirm data has been added by querying the tables
pd.read_sql_query('select * from museums_fy2013', con=engine).head()
# Out:
#    FY2013ID                                       Museum_name  \
# 0         0                    102ND INFANTRY REGIMENT MUSEUM
# 1         1                                      1078 GALLERY
# 2         2             12TH ARMORED DIVISION MEMORIAL MUSEUM
# 3         3                                      1708 GALLERY
# 4         4  1844 CONCORD SCHOOL LOG CABIN HISTORICAL SOCIETY
#
#                                           Legal_name Revenue_2013  Region_code
# 0                 102ND INFANTRY REGIMENT MUSEUM INC        $0.00            1
# 1                                   1078 GALLERY INC   $42,031.00            6
# 2  12TH ARMORED DIVISION MEMORIAL MUSEUM FOUNDATI...  $425,152.00            5
# 3                                   1708 GALLERY INC  $328,248.00            3
# 4   1844 CONCORD SCHOOL LOG CABIN HISTORICAL SOCIETY        $0.00            4

# %%
# confirm data has been added by querying the tables
pd.read_sql_query('select * from museums_fy2015', con=engine).head()
# Out:
#    FY2015ID                                     Common_name  \
# 0         0                           100TH MERIDIAN MUSEUM
# 1         1                  102ND INFANTRY REGIMENT MUSEUM
# 2         2  103RD OHIO VOLUNTEER INFANTRY CIVIL WAR MUSEUM
# 3         3                                    1078 GALLERY
# 4         4                                FORT DRUM MUSEUM
#
#                                   Legal_name       Phone  \
# 0                      100TH MERIDIAN MUSEUM  3087841100
# 1         102ND INFANTRY REGIMENT MUSEUM INC  2037846851
# 2              103RD OVI MEMORIAL FOUNDATION  4409492790
# 3                           1078 GALLERY INC  5303431973
# 4  10TH MOUNTAIN DIVISION & FORT DRUM MUSEUM  3157740391
#
#                                               Weburl Revenue_2015       Long  \
# 0                                                            None  -99.98338
# 1                            HTTP://WHMILMUSEUM.COM/        $0.00  -72.96175
# 2                                                      $13,913.00  -82.06886
# 3                                                      $42,031.00 -121.83653
# 4  HTTP://WWW.DRUM.ARMY.MIL/ABOUTFORTDRUM/PAGES/F...         None  -75.77208
#
#         Lat
# 0  40.85963
# 1  41.27210
# 2  41.50073
# 3  39.72540
# 4  44.04050

# %%
# confirm data has been added by querying the tables
pd.read_sql_query('select * from museums_location', con=engine).head()
# Out:
#    LocationID                                     Museum_name  \
# 0           0                           100TH MERIDIAN MUSEUM
# 1           1                  102ND INFANTRY REGIMENT MUSEUM
# 2           2  103RD OHIO VOLUNTEER INFANTRY CIVIL WAR MUSEUM
# 3           3                                    1078 GALLERY
# 4           4                                FORT DRUM MUSEUM
#
#                                   Legal_name     Museum_type  \
# 0                      100TH MERIDIAN MUSEUM  GENERAL MUSEUM
# 1         102ND INFANTRY REGIMENT MUSEUM INC  GENERAL MUSEUM
# 2              103RD OVI MEMORIAL FOUNDATION  GENERAL MUSEUM
# 3                           1078 GALLERY INC      ART MUSEUM
# 4  10TH MOUNTAIN DIVISION & FORT DRUM MUSEUM  GENERAL MUSEUM
#
#                             Street_address        City State  Zip_code
# 0                             206 E 8TH ST       COZAD    NE     69130
# 1                          30 HOOD TERRACE  WEST HAVEN    CT      6516
# 2                       5501 E LAKE RD OFC      LORAIN    OH     44054
# 3                          820 BROADWAY ST       CHICO    CA     95928
# 4  BUILDING P-10502, SOUTH RIVA RIDGE LOOP   FORT DRUM    NY     13602
